# %%
import keras
import keras.backend as K
from keras.layers.core import Activation
from keras.models import Sequential,load_model
from keras.models import Model
from keras.layers import Input, Dense, LSTM, Activation, Masking, Dropout, Conv1D, GlobalAveragePooling1D, MaxPooling1D, Add
from keras.callbacks import History
from keras import callbacks

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from sklearn import preprocessing
np.random.seed(1234)  
PYTHONHASHSEED = 0

# define path to save model
model_path = './reg-fd3/regression_model.h5'
path = './reg-fd3'

# read training data - It is the aircraft engine run-to-failure data.
train_df = pd.read_csv('CMAPSSData/train_FD003.txt', sep=" ", header=None)
train_df.drop(train_df.columns[[4,5,9, 10,14,18,20,22, 23, 26, 27]], axis=1, inplace=True)

train_df.columns = ['id', 'cycle', 'setting1', 'setting2', 's2', 's3','s4', 's7', 's8', 's9', 's11', 's12', 's13',
                     's15', 's17', 's20', 's21']

train_df = train_df.sort_values(['id','cycle'])

# read test data - It is the aircraft engine operating data without failure events recorded.
test_df = pd.read_csv('CMAPSSData/test_FD003.txt', sep=" ", header=None)
test_df.drop(test_df.columns[[4,5,9, 10,14,18,20,22, 23, 26, 27]], axis=1, inplace=True)
test_df.columns = ['id', 'cycle', 'setting1', 'setting2', 's2', 's3','s4', 's7', 's8', 's9', 's11', 's12', 's13',
                     's15', 's17', 's20', 's21']

truth_df = pd.read_csv('CMAPSSData/RUL_FD003.txt', sep=" ", header=None)
truth_df.drop(truth_df.columns[[1]], axis=1, inplace=True)

# Data Labeling - generate column RUL(Remaining Usefull Life or Time to Failure)
rul = pd.DataFrame(train_df.groupby('id')['cycle'].max()).reset_index()
rul.columns = ['id', 'max']
train_df = train_df.merge(rul, on=['id'], how='left')
train_df['RUL'] = train_df['max'] - train_df['cycle']
train_df.drop('max', axis=1, inplace=True)

w1 = 30
w0 = 15
train_df['label1'] = np.where(train_df['RUL'] <= w1, 1, 0 )
train_df['label2'] = train_df['label1']
train_df.loc[train_df['RUL'] <= w0, 'label2'] = 2

# MinMax normalization (from 0 to 1)
train_df['cycle_norm'] = train_df['cycle']
cols_normalize = train_df.columns.difference(['id','cycle','RUL','label1','label2'])
min_max_scaler = preprocessing.MinMaxScaler()
norm_train_df = pd.DataFrame(min_max_scaler.fit_transform(train_df[cols_normalize]), 
                             columns=cols_normalize, 
                             index=train_df.index)
join_df = train_df[train_df.columns.difference(cols_normalize)].join(norm_train_df)
train_df = join_df.reindex(columns = train_df.columns)

# MinMax normalization (from 0 to 1)
test_df['cycle_norm'] = test_df['cycle']
norm_test_df = pd.DataFrame(min_max_scaler.transform(test_df[cols_normalize]), 
                            columns=cols_normalize, 
                            index=test_df.index)
test_join_df = test_df[test_df.columns.difference(cols_normalize)].join(norm_test_df)
test_df = test_join_df.reindex(columns = test_df.columns)
test_df = test_df.reset_index(drop=True)
print(test_df.head())

rul = pd.DataFrame(test_df.groupby('id')['cycle'].max()).reset_index()
rul.columns = ['id', 'max']
truth_df.columns = ['more']
truth_df['id'] = truth_df.index + 1
truth_df['max'] = rul['max'] + truth_df['more']
truth_df.drop('more', axis=1, inplace=True)

# generate RUL for test data
test_df = test_df.merge(truth_df, on=['id'], how='left')
test_df['RUL'] = test_df['max'] - test_df['cycle']
test_df.drop('max', axis=1, inplace=True)

# generate label columns w0 and w1 for test data
test_df['label1'] = np.where(test_df['RUL'] <= w1, 1, 0 )
test_df['label2'] = test_df['label1']
test_df.loc[test_df['RUL'] <= w0, 'label2'] = 2

# pick a large window size of 50 cycles
sequence_length = 50

# function to reshape features into (samples, time steps, features) 
def gen_sequence(id_df, seq_length, seq_cols):
    data_matrix = id_df[seq_cols].values
    num_elements = data_matrix.shape[0]
    for start, stop in zip(range(0, num_elements-seq_length), range(seq_length, num_elements)):
        yield data_matrix[start:stop, :]
        
# pick the feature columns 
sensor_cols = ['s2', 's3','s4', 's7', 's8', 's9', 's11', 's12', 's13','s15', 's17', 's20', 's21']
sequence_cols = ['setting1', 'setting2', 'cycle_norm']
sequence_cols.extend(sensor_cols)

val=list(gen_sequence(train_df[train_df['id']==1], sequence_length, sequence_cols))
print(len(val))

seq_gen = (list(gen_sequence(train_df[train_df['id']==id], sequence_length, sequence_cols)) 
           for id in train_df['id'].unique())

# generate sequences and convert to numpy array
seq_array = np.concatenate(list(seq_gen)).astype(np.float32)
print(seq_array.shape)

# function to generate labels
def gen_labels(id_df, seq_length, label):
    data_matrix = id_df[label].values
    num_elements = data_matrix.shape[0]
    return data_matrix[seq_length:num_elements, :]

# generate labels
label_gen = [gen_labels(train_df[train_df['id']==id], sequence_length, ['RUL']) 
             for id in train_df['id'].unique()]

label_array = np.concatenate(label_gen).astype(np.float32)
label_array.shape

def r2_keras(y_true, y_pred):
    """Coefficient of Determination 
    """
    SS_res =  K.sum(K.square( y_true - y_pred ))
    SS_tot = K.sum(K.square( y_true - K.mean(y_true) ) )
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

nb_features = seq_array.shape[2]
nb_out = label_array.shape[1]

history = History()

input_layer = Input(shape=(sequence_length, nb_features))
x = Conv1D(50, 6, activation = 'relu')(input_layer)
a = Conv1D(50, 6, activation = 'relu')(x)
x = Conv1D(50, 6, activation = 'relu')(x)
b = Add()([a,x]) # SKIP CONNECTION ADDED
x = MaxPooling1D(3)(b)
x = Conv1D(100, 6, activation = 'relu')(x)
x = Conv1D(100, 6, activation = 'relu')(x)
x = MaxPooling1D(3)(x)
x = Dropout(0.2)(x)
x = LSTM( units=50, input_shape=(1,100), return_sequences=True)(x)
x = LSTM( units=100, return_sequences=True)(x)
c = LSTM( units=100, return_sequences=True)(x)
x = LSTM( units=100, return_sequences=True)(x)
d = Add()([c,x]) # SKIP CONNECTION ADDED
x = GlobalAveragePooling1D()(x)
x = Dropout(0.5)(x)
output_layer = Dense(units=nb_out, activation ='linear')(x)
model = Model(input_layer, output_layer)

model.compile(loss='mean_squared_error', optimizer='rmsprop',metrics=['mean_absolute_error','mean_squared_error', keras.metrics.RootMeanSquaredError(), r2_keras])

print(model.summary())

# fit the network
model.fit(seq_array, label_array, epochs=100, batch_size=16, validation_split=0.1, verbose=1, callbacks = [history,
        keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=10, verbose=0, mode='min'),
        keras.callbacks.ModelCheckpoint(model_path,monitor='val_loss', save_best_only=True, mode='min', verbose=0)])
# Out:
#    id  cycle  setting1  setting2        s2        s3        s4        s7  \
# 0   1      1  0.401163  0.153846  0.257611  0.345077  0.309984  0.237069
# 1   1      2  0.534884  0.307692  0.276347  0.402427  0.340718  0.215038
# 2   1      3  0.581395  0.230769  0.196721  0.342141  0.231825  0.229885
# 3   1      4  0.656977  0.538462  0.318501  0.395968  0.285179  0.238027
# 4   1      5  0.494186  0.538462  0.379391  0.484048  0.293292  0.217912
#
#          s8        s9       s11       s12       s13       s15       s17  \
# 0  0.605882  0.141748  0.228571  0.209883  0.601190  0.530420  0.272727
# 1  0.611765  0.131950  0.222857  0.207845  0.642857  0.603332  0.272727
# 2  0.629412  0.170726  0.262857  0.220581  0.601190  0.480444  0.272727
# 3  0.611765  0.171281  0.325714  0.238411  0.613095  0.518107  0.363636
# 4  0.652941  0.141471  0.142857  0.210902  0.619048  0.623612  0.272727
#
#         s20       s21  cycle_norm
# 0  0.535714  0.532702    0.000000
# 1  0.517857  0.564153    0.001908
# 2  0.553571  0.511921    0.003817
# 3  0.476190  0.561833    0.005725
# 4  0.547619  0.484646    0.007634
# 209
# (19720, 50, 16)
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 50, 16)]     0           []
#
#  conv1d_5 (Conv1D)              (None, 45, 50)       4850        ['input_2[0][0]']
#
#  conv1d_6 (Conv1D)              (None, 40, 50)       15050       ['conv1d_5[0][0]']
#
#  conv1d_7 (Conv1D)              (None, 40, 50)       15050       ['conv1d_5[0][0]']
#
#  add_2 (Add)                    (None, 40, 50)       0           ['conv1d_6[0][0]',
#                                                                   'conv1d_7[0][0]']
#
#  max_pooling1d_2 (MaxPooling1D)  (None, 13, 50)      0           ['add_2[0][0]']
#
#  conv1d_8 (Conv1D)              (None, 8, 100)       30100       ['max_pooling1d_2[0][0]']
#
#  conv1d_9 (Conv1D)              (None, 3, 100)       60100       ['conv1d_8[0][0]']
#
#  max_pooling1d_3 (MaxPooling1D)  (None, 1, 100)      0           ['conv1d_9[0][0]']
#
#  dropout_2 (Dropout)            (None, 1, 100)       0           ['max_pooling1d_3[0][0]']
#
#  lstm_4 (LSTM)                  (None, 1, 50)        30200       ['dropout_2[0][0]']
#
#  lstm_5 (LSTM)                  (None, 1, 100)       60400       ['lstm_4[0][0]']
#
#  lstm_7 (LSTM)                  (None, 1, 100)       80400       ['lstm_5[0][0]']
#
#  global_average_pooling1d_1 (Gl  (None, 100)         0           ['lstm_7[0][0]']
#  obalAveragePooling1D)
#
#  dropout_3 (Dropout)            (None, 100)          0           ['global_average_pooling1d_1[0][0
#                                                                  ]']
#
#  dense_1 (Dense)                (None, 1)            101         ['dropout_3[0][0]']
#
# ==================================================================================================
# Total params: 296,251
# Trainable params: 296,251
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Epoch 1/100
# 1110/1110 [==============================] - 14s 9ms/step - loss: 12860.4258 - mean_absolute_error: 82.0081 - mean_squared_error: 12860.4258 - root_mean_squared_error: 113.4038 - r2_keras: -0.8018 - val_loss: 13092.1689 - val_mean_absolute_error: 82.3616 - val_mean_squared_error: 13092.1689 - val_root_mean_squared_error: 114.4210 - val_r2_keras: -593.8190
# Epoch 2/100
#   22/1110 [..............................] - ETA: 8s - loss: 8750.5791 - mean_absolute_error: 68.6589 - mean_squared_error: 8750.5791 - root_mean_squared_error: 93.5445 - r2_keras: -0.2293
# /Users/shrutirajvanshsingh/opt/anaconda3/lib/python3.8/site-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# 1110/1110 [==============================] - 9s 8ms/step - loss: 8137.9399 - mean_absolute_error: 67.5160 - mean_squared_error: 8137.9399 - root_mean_squared_error: 90.2105 - r2_keras: -0.1205 - val_loss: 11445.1768 - val_mean_absolute_error: 83.4938 - val_mean_squared_error: 11445.1768 - val_root_mean_squared_error: 106.9821 - val_r2_keras: -548.5321
# Epoch 3/100
# 1110/1110 [==============================] - 9s 8ms/step - loss: 7877.6084 - mean_absolute_error: 68.2049 - mean_squared_error: 7877.6084 - root_mean_squared_error: 88.7559 - r2_keras: -0.1281 - val_loss: 11350.1602 - val_mean_absolute_error: 84.0334 - val_mean_squared_error: 11350.1602 - val_root_mean_squared_error: 106.5371 - val_r2_keras: -548.1896
# Epoch 4/100
# 1110/1110 [==============================] - 9s 8ms/step - loss: 7870.9712 - mean_absolute_error: 68.3057 - mean_squared_error: 7870.9712 - root_mean_squared_error: 88.7185 - r2_keras: -0.1304 - val_loss: 11347.3330 - val_mean_absolute_error: 84.0531 - val_mean_squared_error: 11347.3330 - val_root_mean_squared_error: 106.5239 - val_r2_keras: -548.1970
# Epoch 5/100
# 1110/1110 [==============================] - 9s 8ms/step - loss: 6511.3745 - mean_absolute_error: 57.3536 - mean_squared_error: 6511.3745 - root_mean_squared_error: 80.6931 - r2_keras: 0.1091 - val_loss: 7143.0117 - val_mean_absolute_error: 55.8222 - val_mean_squared_error: 7143.0117 - val_root_mean_squared_error: 84.5163 - val_r2_keras: -303.0456
# Epoch 6/100
# 1110/1110 [==============================] - 9s 8ms/step - loss: 3615.0044 - mean_absolute_error: 38.0597 - mean_squared_error: 3615.0044 - root_mean_squared_error: 60.1249 - r2_keras: 0.5313 - val_loss: 7397.7871 - val_mean_absolute_error: 73.2922 - val_mean_squared_error: 7397.7871 - val_root_mean_squared_error: 86.0104 - val_r2_keras: -327.4102
# Epoch 7/100
# 1110/1110 [==============================] - 9s 8ms/step - loss: 2721.8281 - mean_absolute_error: 33.4718 - mean_squared_error: 2721.8281 - root_mean_squared_error: 52.1711 - r2_keras: 0.6289 - val_loss: 4614.0918 - val_mean_absolute_error: 43.2039 - val_mean_squared_error: 4614.0918 - val_root_mean_squared_error: 67.9271 - val_r2_keras: -196.9897
# Epoch 8/100
# 1110/1110 [==============================] - 9s 8ms/step - loss: 2326.3167 - mean_absolute_error: 31.3117 - mean_squared_error: 2326.3167 - root_mean_squared_error: 48.2319 - r2_keras: 0.6733 - val_loss: 5564.7983 - val_mean_absolute_error: 46.0480 - val_mean_squared_error: 5564.7983 - val_root_mean_squared_error: 74.5976 - val_r2_keras: -240.0539
# Epoch 9/100
# 1110/1110 [==============================] - 9s 8ms/step - loss: 2072.8120 - mean_absolute_error: 29.7099 - mean_squared_error: 2072.8120 - root_mean_squared_error: 45.5281 - r2_keras: 0.7084 - val_loss: 2602.7349 - val_mean_absolute_error: 31.3775 - val_mean_squared_error: 2602.7349 - val_root_mean_squared_error: 51.0170 - val_r2_keras: -107.3687
# Epoch 10/100
# 1110/1110 [==============================] - 9s 8ms/step - loss: 1932.0189 - mean_absolute_error: 28.7115 - mean_squared_error: 1932.0189 - root_mean_squared_error: 43.9547 - r2_keras: 0.7233 - val_loss: 4669.9404 - val_mean_absolute_error: 40.3189 - val_mean_squared_error: 4669.9404 - val_root_mean_squared_error: 68.3370 - val_r2_keras: -199.3982
# Epoch 11/100
# 1110/1110 [==============================] - 9s 8ms/step - loss: 1800.7031 - mean_absolute_error: 27.9411 - mean_squared_error: 1800.7031 - root_mean_squared_error: 42.4347 - r2_keras: 0.7419 - val_loss: 4481.3286 - val_mean_absolute_error: 45.2706 - val_mean_squared_error: 4481.3286 - val_root_mean_squared_error: 66.9427 - val_r2_keras: -187.3517
# Epoch 12/100
# 1110/1110 [==============================] - 9s 8ms/step - loss: 1759.4423 - mean_absolute_error: 27.3678 - mean_squared_error: 1759.4423 - root_mean_squared_error: 41.9457 - r2_keras: 0.7447 - val_loss: 2325.2742 - val_mean_absolute_error: 34.8467 - val_mean_squared_error: 2325.2742 - val_root_mean_squared_error: 48.2211 - val_r2_keras: -97.0682
# Epoch 13/100
# 1110/1110 [==============================] - 9s 8ms/step - loss: 1711.7332 - mean_absolute_error: 27.0051 - mean_squared_error: 1711.7332 - root_mean_squared_error: 41.3731 - r2_keras: 0.7500 - val_loss: 5002.3184 - val_mean_absolute_error: 42.6336 - val_mean_squared_error: 5002.3184 - val_root_mean_squared_error: 70.7271 - val_r2_keras: -210.7027
# Epoch 14/100
# 1110/1110 [==============================] - 9s 8ms/step - loss: 1602.5598 - mean_absolute_error: 26.1152 - mean_squared_error: 1602.5598 - root_mean_squared_error: 40.0320 - r2_keras: 0.7588 - val_loss: 2786.8086 - val_mean_absolute_error: 34.3843 - val_mean_squared_error: 2786.8086 - val_root_mean_squared_error: 52.7902 - val_r2_keras: -116.5963
# Epoch 15/100
# 1110/1110 [==============================] - 9s 8ms/step - loss: 1524.6400 - mean_absolute_error: 25.3690 - mean_squared_error: 1524.6400 - root_mean_squared_error: 39.0466 - r2_keras: 0.7757 - val_loss: 3535.7209 - val_mean_absolute_error: 42.4150 - val_mean_squared_error: 3535.7209 - val_root_mean_squared_error: 59.4619 - val_r2_keras: -153.0190
# Epoch 16/100
# 1110/1110 [==============================] - 9s 8ms/step - loss: 1529.0734 - mean_absolute_error: 25.1847 - mean_squared_error: 1529.0734 - root_mean_squared_error: 39.1034 - r2_keras: 0.7722 - val_loss: 4557.5498 - val_mean_absolute_error: 41.1260 - val_mean_squared_error: 4557.5498 - val_root_mean_squared_error: 67.5096 - val_r2_keras: -197.5604
# Epoch 17/100
# 1110/1110 [==============================] - 9s 8ms/step - loss: 1415.0336 - mean_absolute_error: 24.3737 - mean_squared_error: 1415.0336 - root_mean_squared_error: 37.6169 - r2_keras: 0.7868 - val_loss: 3996.8635 - val_mean_absolute_error: 41.4763 - val_mean_squared_error: 3996.8635 - val_root_mean_squared_error: 63.2208 - val_r2_keras: -164.8561
# Epoch 18/100
# 1110/1110 [==============================] - 9s 8ms/step - loss: 1368.0127 - mean_absolute_error: 23.9605 - mean_squared_error: 1368.0127 - root_mean_squared_error: 36.9867 - r2_keras: 0.7975 - val_loss: 3440.3994 - val_mean_absolute_error: 37.8127 - val_mean_squared_error: 3440.3994 - val_root_mean_squared_error: 58.6549 - val_r2_keras: -147.9818
# Epoch 19/100
# 1110/1110 [==============================] - 9s 8ms/step - loss: 1344.1802 - mean_absolute_error: 23.7201 - mean_squared_error: 1344.1802 - root_mean_squared_error: 36.6631 - r2_keras: 0.8032 - val_loss: 3913.4780 - val_mean_absolute_error: 37.9696 - val_mean_squared_error: 3913.4780 - val_root_mean_squared_error: 62.5578 - val_r2_keras: -173.4691
# Epoch 20/100
# 1110/1110 [==============================] - 10s 9ms/step - loss: 1267.4795 - mean_absolute_error: 23.0998 - mean_squared_error: 1267.4795 - root_mean_squared_error: 35.6017 - r2_keras: 0.8017 - val_loss: 2827.9114 - val_mean_absolute_error: 31.9884 - val_mean_squared_error: 2827.9114 - val_root_mean_squared_error: 53.1781 - val_r2_keras: -117.6844
# Epoch 21/100
# 1110/1110 [==============================] - 10s 9ms/step - loss: 1161.6071 - mean_absolute_error: 22.2168 - mean_squared_error: 1161.6071 - root_mean_squared_error: 34.0824 - r2_keras: 0.8192 - val_loss: 3506.0322 - val_mean_absolute_error: 34.8296 - val_mean_squared_error: 3506.0322 - val_root_mean_squared_error: 59.2118 - val_r2_keras: -144.7116
# Epoch 22/100
# 1110/1110 [==============================] - 9s 8ms/step - loss: 1144.1475 - mean_absolute_error: 21.8462 - mean_squared_error: 1144.1475 - root_mean_squared_error: 33.8252 - r2_keras: 0.8249 - val_loss: 3502.8577 - val_mean_absolute_error: 34.4857 - val_mean_squared_error: 3502.8577 - val_root_mean_squared_error: 59.1849 - val_r2_keras: -148.8001

# %%
# list all data in history
print(history.history.keys())
# Out:
# dict_keys(['loss', 'mean_absolute_error', 'mean_squared_error', 'root_mean_squared_error', 'r2_keras', 'val_loss', 'val_mean_absolute_error', 'val_mean_squared_error', 'val_root_mean_squared_error', 'val_r2_keras'])

# %%
# summarize history for R^2
fig_acc = plt.figure(figsize=(10, 10))
plt.plot(history.history['r2_keras'])
plt.plot(history.history['val_r2_keras'])
plt.title('model r^2')
plt.ylabel('R^2')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
fig_acc.savefig(path+"/model_r2.png")

# %%
# summarize history for MAE
fig_acc = plt.figure(figsize=(10, 10))
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('model MAE')
plt.ylabel('MAE')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
fig_acc.savefig(path+"/model_mae.png")

# %%
# summarize history for Loss
fig_acc = plt.figure(figsize=(10, 10))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
fig_acc.savefig(path+"/model_regression_loss.png")

# %%
# summarize history for MSE
fig_acc = plt.figure(figsize=(10, 10))
plt.plot(history.history['mean_squared_error'])
plt.plot(history.history['val_mean_squared_error'])
plt.title('model MSE')
plt.ylabel('MSE')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
fig_acc.savefig(path+"/model_mse.png")

# %%
# summarize history for RMSE
fig_acc = plt.figure(figsize=(10, 10))
plt.plot(history.history['root_mean_squared_error'])
plt.plot(history.history['val_root_mean_squared_error'])
plt.title('model RMSE')
plt.ylabel('RMSE')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
fig_acc.savefig(path+"/model_mse.png")

# %%
# training metrics
scores = model.evaluate(seq_array, label_array, verbose=1, batch_size=200)
print('\nMAE: {}'.format(scores[1]))
print('\nMSE: {}'.format(scores[2]))
print('\nRMSE: {}'.format(scores[3]))
print('\nR^2: {}'.format(scores[4]))
scores
# Out:
# 99/99 [==============================] - 1s 8ms/step - loss: 1231.0653 - mean_absolute_error: 20.9880 - mean_squared_error: 1231.0653 - root_mean_squared_error: 35.0865 - r2_keras: 0.6560
#
# MAE: 20.987985610961914
#
# MSE: 1231.0653076171875
#
# RMSE: 35.08654022216797
#
# R^2: 0.6560105681419373
# [1231.0653076171875,
#  20.987985610961914,
#  1231.0653076171875,
#  35.08654022216797,
#  0.6560105681419373]

# %%
y_pred = model.predict(seq_array,verbose=1, batch_size=200)
y_true = label_array

test_set = pd.DataFrame(y_pred)
test_set.to_csv(path+'submit_train.csv', index = None)
# Out:
# 99/99 [==============================] - 2s 8ms/step

# %%
seq_array_test_last = [test_df[test_df['id']==id][sequence_cols].values[-sequence_length:] 
                       for id in test_df['id'].unique() if len(test_df[test_df['id']==id]) >= sequence_length]

seq_array_test_last = np.asarray(seq_array_test_last).astype(np.float32)

y_mask = [len(test_df[test_df['id']==id]) >= sequence_length for id in test_df['id'].unique()]
label_array_test_last = test_df.groupby('id')['RUL'].nth(-1)[y_mask].values
label_array_test_last = label_array_test_last.reshape(label_array_test_last.shape[0],1).astype(np.float32)

if os.path.isfile(model_path):
    estimator = load_model(model_path,custom_objects={'r2_keras': r2_keras})

    # test metrics
    scores_test = estimator.evaluate(seq_array_test_last, label_array_test_last, verbose=2)
    print('\nMAE: {}'.format(scores[1]))
    print('\nMSE: {}'.format(scores[2]))
    print('\nRMSE: {}'.format(scores[3]))
    print('\nR^2: {}'.format(scores[4]))

    y_pred_test = estimator.predict(seq_array_test_last)
    y_true_test = label_array_test_last

    test_set = pd.DataFrame(y_pred_test)
    test_set.to_csv('submit_test.csv', index = None)

    # Plot in blue color the predicted data and in green color the
    # actual data to verify visually the accuracy of the model.
    fig_verify = plt.figure(figsize=(100, 50))
    plt.plot(y_pred_test, color="blue")
    plt.plot(y_true_test, color="green")
    plt.title('prediction')
    plt.ylabel('value')
    plt.xlabel('row')
    plt.legend(['predicted', 'actual data'], loc='upper left')
    plt.show()
    fig_verify.savefig(path+"/model_regression_verify.png")
# Out:
# 4/4 - 1s - loss: 2068.8379 - mean_absolute_error: 31.1224 - mean_squared_error: 2068.8379 - root_mean_squared_error: 45.4845 - r2_keras: -6.0799e+07 - 912ms/epoch - 228ms/step
#
# MAE: 20.987985610961914
#
# MSE: 1231.0653076171875
#
# RMSE: 35.08654022216797
#
# R^2: 0.6560105681419373
